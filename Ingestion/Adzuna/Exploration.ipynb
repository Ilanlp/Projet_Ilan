# %%
import pandas as pd
import json

# Charger le fichier JSON
with open("adzuna_results.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Extraire les résultats (liste d'offres d'emploi)
offers = data.get("results", [])

# Convertir en DataFrame
df = pd.DataFrame(offers)

df
# Out:
#                  created                                           location  \
# 0   2025-03-09T04:16:25Z  {'area': ['France'], '__CLASS__': 'Adzuna::API...
# 1   2025-05-24T06:59:12Z  {'display_name': 'Grenoble, Isère', '__CLASS__...
# 2   2025-06-07T08:40:25Z  {'__CLASS__': 'Adzuna::API::Response::Location...
# 3   2025-06-15T09:36:47Z  {'display_name': 'Ile-de-France, France', '__C...
# 4   2025-06-01T05:22:54Z  {'area': ['France', 'Ile-de-France'], '__CLASS...
# 5   2025-06-08T10:05:41Z  {'area': ['France', 'Pays de la Loire', 'Loire...
# 6   2025-05-18T17:09:25Z  {'area': ['France', 'Auvergne-Rhône-Alpes', 'R...
# 7   2025-06-15T09:36:44Z  {'display_name': 'Toulouse, Haute-Garonne', '_...
# 8   2025-05-24T06:55:09Z  {'__CLASS__': 'Adzuna::API::Response::Location...
# 9   2025-06-01T05:08:20Z  {'display_name': 'Paris, Ile-de-France', '__CL...
# 10  2025-06-05T09:21:30Z  {'display_name': 'Paris, Ile-de-France', '__CL...
# ...

# %%
df['description']
# Out:
# 0     Daveo est un cabinet de conseil spécialisé dan...
# 1      Tu as l'esprit d'initiative et tu aimes trava...
# 2     Descriptif du poste : eXalt IT, spécialisée su...
# 3     ▶ Qui sommes-nous ? ➡ SKOTT GROUP est un cabin...
# 4     Nous sommes à la recherche de développeurs Pyt...
# 5     Développeur Python (H/F) Vous êtes passionné(e...
# 6      Coder est une seconde nature pour toi et tu e...
# 7     À propos de TMC TMC est une société internatio...
# 8     Nous recrutons un(e) développeur(se) a pour un...
# 9     Senior / Lead Python Engineer Paris - Hybrid T...
# 10    Contexte : Notre client développe des solution...
# 11     Python, SIG ça te parle ? Tu as déjà intégré ...
# 12    Nous sommes à la recherche d'excellents dévelo...
# 13    Offre pour un CDI : Consultant DataBricks / Py...
# 14    LEAD DEVELOPER PYTHON PARIS (75) 70-90K€ Cette...
# 15    5 Degrés Toulouse est une agence de conseil à ...
# 16    Depuis 2011, Squad s’impose comme un acteur cl...
# ...

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
